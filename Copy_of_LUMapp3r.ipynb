# %% [markdown]
# <a href="https://colab.research.google.com/github/akyrespo/LUNavigatorMap/blob/main/Copy_of_LUMapp3r.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
https://github.com/akyrespo/LUSchoolMap.git
# Out:
#   File "<ipython-input-2-5fe3eecac0ca>", line 1
#     https://github.com/akyrespo/LUSchoolMap.git
#           ^
# SyntaxError: invalid syntax
